# %%
#plot sussed before and after storm surge(for all surges) 
#for different canopy heights
import numpy as np
from netCDF4 import Dataset, num2date
import matplotlib.pyplot as plt
import cftime
import matplotlib.units as munits
from matplotlib.dates import ConciseDateConverter
munits.registry[cftime.DatetimeGregorian] = ConciseDateConverter()
from matplotlib.gridspec import GridSpec
import sys
sys.path.insert(0, '/home/g/g260204/tools/python_skripts/SchismUtils/')
from schism_utils import sort_files, read_data, find_hwlw
import h5py
import pandas as pd
from datetime import datetime,timedelta

# %%
surges= [(2010,315),(2013,30),(2013,338),(2015,10),(2015,317),(2015,333)]#year,day
simpat = '/work/gg0877/g260204/sim_data/SR5yr/'
rsgname = 'srm036_'
nsgname = 'srm020_'
ssgname = 'srm035_'
plotpat = '/work/gg0877/g260204/sim_data/SR5yr/plots/plots/srm203536/'

mthw = (589-499)/100

# %%
#seagrass meadow polygons patchsav.prop
patchpat = '/work/gg0877/g260204/SR5yr/srm024_2010/patchsav.prop'
patchsav = np.genfromtxt(patchpat,delimiter=" ",dtype=np.int32)
tri = Dataset(simpat+rsgname+str(surges[0][0])+'/outputs/schout_1.nc').variables['SCHISM_hgrid_face_nodes'][:,:3]-1
face_sav = np.squeeze(np.where(patchsav[:,1]==1))

##this one first to remove cells where hcan mean is 0!
#ncpat = '/work/gg0877/g260204/sim_data/SR5yr/'+ rsgname + '/outputs'
#files_sorted = sort_files(ncpat)
#hcan  = read_data('ICM_hcansav',files_sorted,ntime=range(0,1))
#hcan[:,patchsav[:,1]==0]=np.nan
#hcan_0 = np.mean(hcan,0)
#face_sav = np.squeeze(np.where(hcan_0>0))

# %%
sed_sum_hcan = np.zeros([7,6,len(surges)]) #subsets, hcansplit, surges
s = 0
for surge in surges:
    year = str(surge[0])
    nsf = surge[1]
    #variable seagrass---------------------------------------------------------------
    ncpat = simpat+rsgname+year+'/outputs'
    files_sorted = sort_files(ncpat)[nsf-1:nsf+2]
    #find index of high water
    elev,elev_time = read_data(['elev','time'],files_sorted,node = 33665)
    nhw = np.argmax(elev)
    trel = (elev_time-elev_time[nhw])/60/60
    #splitting timeseries into subsets of ~6h surrounding hw
    nts = np.linspace(nhw-18,nhw+18,7,dtype='int')
    hcan, nsav = read_data(['ICM_hcansav','ICM_nsav'],files_sorted)
    lai = hcan*nsav*0.002
    tmp_sed = read_data(['SED3D_1','SED3D_2','SED3D_3'],files_sorted)
    lai = lai[:,face_sav]
    #sum different sed fractions, over all layers and rearange into face values
    tmp_sed_sum = np.sum(np.sum(tmp_sed,0),2)
    sed_tri  = np.mean(tmp_sed_sum[:,tri],2)
    sed =sed_tri[:,face_sav]
    #split into subsets 
    #subset,t,face
    lai_subs = [lai[nts[i]:nts[i+1],:] for i in range(len(nts)-1)]
    sed_subs  = [ sed[nts[i]:nts[i+1],:] for i in range(len(nts)-1)]
    time_subs = [trel[nts[i]:nts[i+1]]   for i in range(len(nts)-1)]
    #split by lai  (lai should be in range 0,3
    nhc = [[np.where(                      lai_subs[i]<0.2 ) for i in range(len(nts)-1)], #       lai <0.2
           [np.where((lai_subs[i]>=0.2) & (lai_subs[i]<0.4)) for i in range(len(nts)-1)], #0.2 <= lai <0.4
           [np.where((lai_subs[i]>=0.4) & (lai_subs[i]<0.6)) for i in range(len(nts)-1)], #0.4 <= lai <0.6
           [np.where((lai_subs[i]>=0.6)                    ) for i in range(len(nts)-1)]] #0.6 <= lai
 
    
    #sum of 
    for i in range(len(nts)-1):
        for j in range(4):
            sed_sum_hcan[j+3,i,s] = np.nanmean(sed_subs[i][nhc[j][i]])

    #sum of for all var sg
    for i in range(len(nts)-1):
        sed_sum_hcan[2,i,s] = np.nanmean(sed_subs[i])
 
    #static seagrass -----------------------------------------------------------------------------------
    ncpat = simpat+ssgname+year+'/outputs'
    files_sorted = sort_files(ncpat)[nsf-1:nsf+2]

    tmp_sed = read_data(['SED3D_1','SED3D_2','SED3D_3'],files_sorted)
    #sum different sed fractions, over all layers and rearange into face values
    tmp_sed_sum = np.sum(np.sum(tmp_sed,0),2)
    sed_tri  = np.mean(tmp_sed_sum[:,tri],2)
    sed =sed_tri[:,face_sav]
    #split into subsets 
    #subset,t,face
    sed_subs  = [ sed[nts[i]:nts[i+1],:] for i in range(len(nts)-1)]
    time_subs = [trel[nts[i]:nts[i+1]]   for i in range(len(nts)-1)]

    #sum of 
    for i in range(len(nts)-1):
        sed_sum_hcan[1,i,s] = np.nanmean(sed_subs[i])

    # no seagrass----------------------------------------------------------------------------------------
    ncpat = simpat+nsgname+year+'/outputs'
    files_sorted = sort_files(ncpat)[nsf-1:nsf+2]

    tmp_sed = read_data(['SED3D_1','SED3D_2','SED3D_3'],files_sorted)
    #sum different sed fractions, over all layers and rearange into face values
    tmp_sed_sum = np.sum(np.sum(tmp_sed,0),2)
    sed_tri  = np.mean(tmp_sed_sum[:,tri],2)
    sed =sed_tri[:,face_sav]
    #split into subsets 
    #subset,t,face
    sed_subs  = [ sed[nts[i]:nts[i+1],:] for i in range(len(nts)-1)]
    time_subs = [trel[nts[i]:nts[i+1]]   for i in range(len(nts)-1)]

    #sum of 
    for i in range(len(nts)-1):
        sed_sum_hcan[0,i,s] = np.nanmean(sed_subs[i])
        
    #plotting--------------------------------------------------------------------------------------------
    #create labels for time axis
    tlabel = [time_subs[i][0] for i in range(len(nts)-1)]
    tlabel.append(time_subs[5][-1])
    
    #plot separately hcan
    fig, ax = plt.subplots()
    im = ax.imshow(sed_sum_hcan[:,:,s],origin='lower')
    cbar = ax.figure.colorbar(im)
    cbar.ax.set_ylabel('SSC [g/L]')
    ax.set_yticks(np.arange(7), labels=['no sg','static (0.41)','variable (0.11)','<0.2','0.2-0.4','0.4-0.6','>0.6'])
    ax.set_ylabel('LAI')
    ax.set_xticks(np.arange(len(nts))-0.5,tlabel)
    ax.set_xlabel('time relative to maximum high water level [h]')
    ax.plot(np.arange(len(nts))-0.5,np.ones(len(nts))*2.5,'r')
    plt.savefig(plotpat+'stromevent_sussed_heatmap_lai'+str(surge)+'_meanvarsg.png')
    
    s+=1
# Out:
# Loading files (srm036_2010, elev): 100%|██████████| 3/3 [00:00<00:00,  4.76it/s]
# Loading files (srm036_2010, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00,  4.13it/s]
# Loading files (srm036_2010, SED3D_1): 100%|██████████| 3/3 [00:03<00:00,  1.18s/it]
# /tmp/ipykernel_1675720/3072449719.py:38: RuntimeWarning: Mean of empty slice
#   sed_sum_hcan[j+3,i,s] = np.nanmean(sed_subs[i][nhc[j][i]])
# Loading files (srm035_2010, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.64s/it]
# Loading files (srm020_2010, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.84s/it]
# Loading files (srm036_2013, elev): 100%|██████████| 3/3 [00:00<00:00,  7.54it/s]
# Loading files (srm036_2013, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00, 11.29it/s]
# Loading files (srm036_2013, SED3D_1): 100%|██████████| 3/3 [00:06<00:00,  2.11s/it]
# Loading files (srm035_2013, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.65s/it]
# Loading files (srm020_2013, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.78s/it]
# Loading files (srm036_2013, elev): 100%|██████████| 3/3 [00:00<00:00, 18.31it/s]
# Loading files (srm036_2013, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00, 15.26it/s]
# Loading files (srm036_2013, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]
# Loading files (srm035_2013, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.62s/it]
# Loading files (srm020_2013, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.75s/it]
# Loading files (srm036_2015, elev): 100%|██████████| 3/3 [00:00<00:00,  8.49it/s]
# Loading files (srm036_2015, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00, 15.97it/s]
# Loading files (srm036_2015, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.68s/it]
# Loading files (srm035_2015, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.54s/it]
# Loading files (srm020_2015, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.75s/it]
# Loading files (srm036_2015, elev): 100%|██████████| 3/3 [00:00<00:00,  7.57it/s]
# Loading files (srm036_2015, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00, 16.63it/s]
# Loading files (srm036_2015, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.85s/it]
# Loading files (srm035_2015, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.85s/it]
# Loading files (srm020_2015, SED3D_1): 100%|██████████| 3/3 [00:08<00:00,  2.89s/it]
# Loading files (srm036_2015, elev): 100%|██████████| 3/3 [00:00<00:00,  8.87it/s]
# Loading files (srm036_2015, ICM_hcansav): 100%|██████████| 3/3 [00:00<00:00, 15.07it/s]
# Loading files (srm036_2015, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.67s/it]
# Loading files (srm035_2015, SED3D_1): 100%|██████████| 3/3 [00:07<00:00,  2.61s/it]
# Loading files (srm020_2015, SED3D_1): 100%|██████████| 3/3 [00:09<00:00,  3.13s/it]

# %%
#plot mean for all
fig, ax = plt.subplots()
im = ax.imshow(np.nanmean(sed_sum_hcan,2),origin='lower')
cbar = ax.figure.colorbar(im)
cbar.ax.set_ylabel('SSC [g/L]')
ax.set_yticks(np.arange(7), labels=['no sg','static (0.41)','variable (0.11)','<0.2','0.2-0.4','0.4-0.6','>0.6'])
ax.set_ylabel('LAI')
ax.set_xticks(np.arange(len(nts))-0.5,tlabel)
ax.set_xlabel('time relative to maximum high water level [h]')
ax.plot(np.arange(len(nts))-0.5,np.ones(len(nts))*2.5,'r')
plt.savefig(plotpat+'stromevent_sussed_heatmap_lai_meanvarsg.png')

# %%
0.086*2400*0.002
# Out:
# 0.41279999999999994

# %%
tlabel = [time_subs[i][0] for i in range(len(nts)-1)]
tlabel.append(time_subs[5][-1])

# %%
print(tlabel)
# Out:
# [-18.0, -12.0, -6.0, 0.0, 6.0, 12.0, 17.0]

# %%
[i for i in range(len(nts)-1)]
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
time_subs[5][-1]
# Out:
# 17.0
